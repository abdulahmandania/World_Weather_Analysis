# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# generates latitudes and longitudes & declare each array as a variable
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# pack the latitudes (lats) and longitudes (lngs) as pairs by 
#  zipping them (lat_lngs) with the zip() function.
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create a cities list to store city names.
cities = []

# iterate through the coordinates and retrieve the nearest city using the latitude and longitude pair
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # add a decision statement with the logical operator "not" in 
    # to determine whether the found city is already in the cities list
    if city not in cities:
        # If not, then we'll use the append() function to add it
        cities.append(city)
        
        # We are doing this because among the 1,500 latitudes and longitudes, there might be duplicates, 
        # which will retrieve duplicate cities, and we want to be sure we capture only the unique cities.
        
        # Print the city count to confirm sufficient count.
len(cities)
# Out:
# 723

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"] 
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | longyearbyen
# Processing Record 3 of Set 1 | zaporizhzhya
# Processing Record 4 of Set 1 | iacu
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | airai
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | khash
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | fuling
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | saint george
# Processing Record 16 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 1 | buerarema
# Processing Record 18 of Set 1 | makakilo city
# Processing Record 19 of Set 1 | vila velha
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | atar
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | marzuq
# Processing Record 24 of Set 1 | lorengau
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | bilma
# Processing Record 30 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 31 of Set 1 | armacao dos buzios
# City not found. Skipping...
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | poum
# Processing Record 34 of Set 1 | kismayo
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | chicama
# Processing Record 37 of Set 1 | orange cove
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | mazyr
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | bubaque
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | lagoa
# Processing Record 46 of Set 1 | saint-pierre
# Processing Record 47 of Set 1 | nizwa
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | mahibadhoo
# Processing Record 50 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | provideniya
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | laguna
# Processing Record 6 of Set 2 | ahipara
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | havre-saint-pierre
# Processing Record 9 of Set 2 | balimo
# City not found. Skipping...
# Processing Record 10 of Set 2 | goderich
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | san patricio
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | sao leopoldo
# Processing Record 16 of Set 2 | olutanga
# Processing Record 17 of Set 2 | cabo san lucas
# Processing Record 18 of Set 2 | sitka
# Processing Record 19 of Set 2 | ayagoz
# Processing Record 20 of Set 2 | saint-augustin
# Processing Record 21 of Set 2 | mount isa
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | sayla
# Processing Record 25 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 2 | coalinga
# Processing Record 27 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | bandarbeyla
# Processing Record 30 of Set 2 | chapleau
# Processing Record 31 of Set 2 | vinh long
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | borlange
# City not found. Skipping...
# Processing Record 35 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 2 | besikduzu
# Processing Record 37 of Set 2 | nunoa
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 2 | byron bay
# Processing Record 40 of Set 2 | pangnirtung
# Processing Record 41 of Set 2 | mount gambier
# Processing Record 42 of Set 2 | los llanos de aridane
# Processing Record 43 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 2 | cody
# Processing Record 45 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 46 of Set 2 | naenwa
# City not found. Skipping...
# Processing Record 47 of Set 2 | fare
# Processing Record 48 of Set 2 | rocha
# Processing Record 49 of Set 2 | katherine
# Processing Record 50 of Set 2 | morondava
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | klaksvik
# Processing Record 3 of Set 3 | taoudenni
# Processing Record 4 of Set 3 | ostrovnoy
# Processing Record 5 of Set 3 | pevek
# Processing Record 6 of Set 3 | nanortalik
# Processing Record 7 of Set 3 | namatanai
# Processing Record 8 of Set 3 | cidreira
# Processing Record 9 of Set 3 | saint-philippe
# Processing Record 10 of Set 3 | wau
# Processing Record 11 of Set 3 | tasiilaq
# Processing Record 12 of Set 3 | great falls
# Processing Record 13 of Set 3 | urusha
# Processing Record 14 of Set 3 | north marysville
# City not found. Skipping...
# Processing Record 15 of Set 3 | bathsheba
# Processing Record 16 of Set 3 | tupik
# Processing Record 17 of Set 3 | new norfolk
# Processing Record 18 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 3 | guadalupe y calvo
# Processing Record 20 of Set 3 | playas
# Processing Record 21 of Set 3 | kralendijk
# Processing Record 22 of Set 3 | kualakapuas
# Processing Record 23 of Set 3 | east london
# Processing Record 24 of Set 3 | davidson
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | coihaique
# Processing Record 27 of Set 3 | chumikan
# Processing Record 28 of Set 3 | inhambane
# Processing Record 29 of Set 3 | san quintin
# Processing Record 30 of Set 3 | vila do maio
# Processing Record 31 of Set 3 | geraldton
# Processing Record 32 of Set 3 | quixeramobim
# Processing Record 33 of Set 3 | bengkulu
# Processing Record 34 of Set 3 | abu zabad
# Processing Record 35 of Set 3 | makoshyne
# Processing Record 36 of Set 3 | kapuskasing
# Processing Record 37 of Set 3 | nikolskoye
# Processing Record 38 of Set 3 | sao joao da barra
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | naron
# Processing Record 41 of Set 3 | ola
# Processing Record 42 of Set 3 | pelotas
# Processing Record 43 of Set 3 | abu kamal
# Processing Record 44 of Set 3 | el alto
# Processing Record 45 of Set 3 | luang prabang
# Processing Record 46 of Set 3 | richards bay
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | bethel
# Processing Record 49 of Set 3 | bardiyah
# Processing Record 50 of Set 3 | kodiak
# Processing Record 1 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 4 | port blair
# Processing Record 3 of Set 4 | lompoc
# Processing Record 4 of Set 4 | campbellsville
# Processing Record 5 of Set 4 | sulangan
# Processing Record 6 of Set 4 | umm lajj
# Processing Record 7 of Set 4 | teneguiban
# City not found. Skipping...
# Processing Record 8 of Set 4 | mahebourg
# Processing Record 9 of Set 4 | pangody
# Processing Record 10 of Set 4 | kahului
# Processing Record 11 of Set 4 | sao filipe
# Processing Record 12 of Set 4 | hofn
# Processing Record 13 of Set 4 | kargopol
# Processing Record 14 of Set 4 | isangel
# Processing Record 15 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 4 | svetlyy
# Processing Record 17 of Set 4 | mackenzie
# Processing Record 18 of Set 4 | bushehr
# Processing Record 19 of Set 4 | kamina
# Processing Record 20 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 4 | davila
# Processing Record 22 of Set 4 | clyde river
# Processing Record 23 of Set 4 | mayumba
# Processing Record 24 of Set 4 | oil city
# Processing Record 25 of Set 4 | burica
# City not found. Skipping...
# Processing Record 26 of Set 4 | saint-denis
# Processing Record 27 of Set 4 | yumen
# Processing Record 28 of Set 4 | we
# City not found. Skipping...
# Processing Record 29 of Set 4 | nemuro
# Processing Record 30 of Set 4 | cherskiy
# Processing Record 31 of Set 4 | shingu
# Processing Record 32 of Set 4 | biel
# Processing Record 33 of Set 4 | san carlos de bariloche
# Processing Record 34 of Set 4 | manokwari
# Processing Record 35 of Set 4 | talnakh
# Processing Record 36 of Set 4 | jauharabad
# Processing Record 37 of Set 4 | sinjai
# Processing Record 38 of Set 4 | kedrovyy
# Processing Record 39 of Set 4 | esperance
# Processing Record 40 of Set 4 | chokurdakh
# Processing Record 41 of Set 4 | tazmalt
# Processing Record 42 of Set 4 | keffi
# Processing Record 43 of Set 4 | faanui
# Processing Record 44 of Set 4 | shelburne
# Processing Record 45 of Set 4 | tilichiki
# Processing Record 46 of Set 4 | kaitangata
# Processing Record 47 of Set 4 | yar-sale
# Processing Record 48 of Set 4 | cabedelo
# Processing Record 49 of Set 4 | ukmerge
# Processing Record 50 of Set 4 | amahai
# Processing Record 1 of Set 5 | tongliao
# Processing Record 2 of Set 5 | khasan
# Processing Record 3 of Set 5 | bosaso
# Processing Record 4 of Set 5 | barbosa ferraz
# Processing Record 5 of Set 5 | walvis bay
# Processing Record 6 of Set 5 | hay river
# Processing Record 7 of Set 5 | mangrul pir
# Processing Record 8 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 5 | nha trang
# Processing Record 10 of Set 5 | jamestown
# Processing Record 11 of Set 5 | abu samrah
# Processing Record 12 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 5 | port alfred
# Processing Record 14 of Set 5 | baracoa
# Processing Record 15 of Set 5 | upernavik
# Processing Record 16 of Set 5 | bambanglipuro
# Processing Record 17 of Set 5 | vanavara
# Processing Record 18 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 5 | jumla
# Processing Record 20 of Set 5 | sorland
# Processing Record 21 of Set 5 | murray bridge
# Processing Record 22 of Set 5 | sechura
# Processing Record 23 of Set 5 | baghdad
# Processing Record 24 of Set 5 | nouadhibou
# Processing Record 25 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 5 | porto novo
# Processing Record 27 of Set 5 | qasigiannguit
# Processing Record 28 of Set 5 | tenali
# Processing Record 29 of Set 5 | camana
# Processing Record 30 of Set 5 | kirensk
# Processing Record 31 of Set 5 | vao
# Processing Record 32 of Set 5 | xiongshi
# City not found. Skipping...
# Processing Record 33 of Set 5 | severo-kurilsk
# Processing Record 34 of Set 5 | lata
# Processing Record 35 of Set 5 | gamba
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | vanimo
# Processing Record 38 of Set 5 | santa marta de tormes
# Processing Record 39 of Set 5 | dalaba
# Processing Record 40 of Set 5 | norman wells
# Processing Record 41 of Set 5 | necochea
# Processing Record 42 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 43 of Set 5 | birjand
# Processing Record 44 of Set 5 | wunsiedel
# Processing Record 45 of Set 5 | sioux lookout
# Processing Record 46 of Set 5 | grootfontein
# Processing Record 47 of Set 5 | gospic
# Processing Record 48 of Set 5 | meulaboh
# Processing Record 49 of Set 5 | port-cartier
# Processing Record 50 of Set 5 | lima
# Processing Record 1 of Set 6 | bac lieu
# Processing Record 2 of Set 6 | maxixe
# Processing Record 3 of Set 6 | yulara
# Processing Record 4 of Set 6 | stornoway
# Processing Record 5 of Set 6 | korla
# Processing Record 6 of Set 6 | karratha
# Processing Record 7 of Set 6 | lebu
# Processing Record 8 of Set 6 | caravelas
# Processing Record 9 of Set 6 | mazatlan
# Processing Record 10 of Set 6 | jijiga
# Processing Record 11 of Set 6 | tabou
# Processing Record 12 of Set 6 | eyemouth
# Processing Record 13 of Set 6 | erzin
# Processing Record 14 of Set 6 | zhangjiakou
# Processing Record 15 of Set 6 | fort nelson
# Processing Record 16 of Set 6 | russell
# Processing Record 17 of Set 6 | slave lake
# Processing Record 18 of Set 6 | jardim
# Processing Record 19 of Set 6 | galveston
# Processing Record 20 of Set 6 | nagai
# Processing Record 21 of Set 6 | trenggalek
# Processing Record 22 of Set 6 | mandalgovi
# Processing Record 23 of Set 6 | taltal
# Processing Record 24 of Set 6 | lecce
# Processing Record 25 of Set 6 | tuatapere
# Processing Record 26 of Set 6 | pangkalanbuun
# Processing Record 27 of Set 6 | castro
# Processing Record 28 of Set 6 | bonavista
# Processing Record 29 of Set 6 | effingham
# Processing Record 30 of Set 6 | birin
# Processing Record 31 of Set 6 | nara
# Processing Record 32 of Set 6 | abay
# Processing Record 33 of Set 6 | nuuk
# Processing Record 34 of Set 6 | ust-kut
# Processing Record 35 of Set 6 | ipojuca
# Processing Record 36 of Set 6 | sibolga
# Processing Record 37 of Set 6 | itarema
# Processing Record 38 of Set 6 | opuwo
# Processing Record 39 of Set 6 | port hardy
# Processing Record 40 of Set 6 | pacifica
# Processing Record 41 of Set 6 | najran
# Processing Record 42 of Set 6 | katangli
# Processing Record 43 of Set 6 | havoysund
# Processing Record 44 of Set 6 | santa maria
# Processing Record 45 of Set 6 | sungaipenuh
# Processing Record 46 of Set 6 | codrington
# Processing Record 47 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 6 | antalaha
# Processing Record 49 of Set 6 | gold coast
# Processing Record 50 of Set 6 | mareeba
# Processing Record 1 of Set 7 | lushunkou
# City not found. Skipping...
# Processing Record 2 of Set 7 | antofagasta
# Processing Record 3 of Set 7 | xuddur
# Processing Record 4 of Set 7 | hamilton
# Processing Record 5 of Set 7 | uvat
# Processing Record 6 of Set 7 | oktyabrskiy
# Processing Record 7 of Set 7 | sukumo
# Processing Record 8 of Set 7 | kavieng
# Processing Record 9 of Set 7 | chuy
# Processing Record 10 of Set 7 | maldonado
# Processing Record 11 of Set 7 | manggar
# Processing Record 12 of Set 7 | fortuna
# Processing Record 13 of Set 7 | calama
# Processing Record 14 of Set 7 | zhangye
# Processing Record 15 of Set 7 | havelock
# Processing Record 16 of Set 7 | augusto correa
# Processing Record 17 of Set 7 | salalah
# Processing Record 18 of Set 7 | ilulissat
# Processing Record 19 of Set 7 | arraial do cabo
# Processing Record 20 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 21 of Set 7 | lyman
# Processing Record 22 of Set 7 | deshnok
# Processing Record 23 of Set 7 | porto walter
# Processing Record 24 of Set 7 | plaeng yao
# Processing Record 25 of Set 7 | moron
# Processing Record 26 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 7 | souillac
# Processing Record 28 of Set 7 | shimoda
# Processing Record 29 of Set 7 | narsaq
# Processing Record 30 of Set 7 | genhe
# Processing Record 31 of Set 7 | sao felix do xingu
# Processing Record 32 of Set 7 | krasnoborsk
# Processing Record 33 of Set 7 | srisailam
# Processing Record 34 of Set 7 | mashhad
# Processing Record 35 of Set 7 | pisco
# Processing Record 36 of Set 7 | ban nahin
# Processing Record 37 of Set 7 | solnechnyy
# Processing Record 38 of Set 7 | natal
# Processing Record 39 of Set 7 | yambio
# Processing Record 40 of Set 7 | auki
# Processing Record 41 of Set 7 | flinders
# Processing Record 42 of Set 7 | boden
# Processing Record 43 of Set 7 | itoman
# Processing Record 44 of Set 7 | half moon bay
# Processing Record 45 of Set 7 | pravdinsk
# Processing Record 46 of Set 7 | aklavik
# Processing Record 47 of Set 7 | porto torres
# Processing Record 48 of Set 7 | bambous virieux
# Processing Record 49 of Set 7 | chervona sloboda
# Processing Record 50 of Set 7 | leningradskiy
# Processing Record 1 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 8 | cape canaveral
# Processing Record 3 of Set 8 | rengo
# Processing Record 4 of Set 8 | north platte
# Processing Record 5 of Set 8 | clarence town
# Processing Record 6 of Set 8 | kathu
# Processing Record 7 of Set 8 | nantucket
# Processing Record 8 of Set 8 | gorontalo
# Processing Record 9 of Set 8 | maceio
# Processing Record 10 of Set 8 | majene
# Processing Record 11 of Set 8 | namibe
# Processing Record 12 of Set 8 | oum hadjer
# Processing Record 13 of Set 8 | dawlatabad
# Processing Record 14 of Set 8 | capitan bado
# Processing Record 15 of Set 8 | san cristobal
# Processing Record 16 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 8 | venezuela
# Processing Record 18 of Set 8 | nouakchott
# Processing Record 19 of Set 8 | jawhar
# Processing Record 20 of Set 8 | merauke
# Processing Record 21 of Set 8 | coquimbo
# Processing Record 22 of Set 8 | rapina
# Processing Record 23 of Set 8 | llangefni
# Processing Record 24 of Set 8 | koutiala
# Processing Record 25 of Set 8 | katsuura
# Processing Record 26 of Set 8 | lesogorskiy
# Processing Record 27 of Set 8 | qaanaaq
# Processing Record 28 of Set 8 | santa cruz
# Processing Record 29 of Set 8 | brae
# Processing Record 30 of Set 8 | ulaangom
# Processing Record 31 of Set 8 | jurm
# Processing Record 32 of Set 8 | singleton
# Processing Record 33 of Set 8 | hami
# Processing Record 34 of Set 8 | rafai
# Processing Record 35 of Set 8 | nome
# Processing Record 36 of Set 8 | businga
# Processing Record 37 of Set 8 | mogilno
# Processing Record 38 of Set 8 | soyo
# Processing Record 39 of Set 8 | zhezkazgan
# Processing Record 40 of Set 8 | bilibino
# Processing Record 41 of Set 8 | hovd
# Processing Record 42 of Set 8 | porto velho
# Processing Record 43 of Set 8 | coffs harbour
# Processing Record 44 of Set 8 | portland
# Processing Record 45 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 8 | pimentel
# Processing Record 47 of Set 8 | mehamn
# Processing Record 48 of Set 8 | mitu
# Processing Record 49 of Set 8 | polis
# Processing Record 50 of Set 8 | henties bay
# Processing Record 1 of Set 9 | avera
# Processing Record 2 of Set 9 | belyy yar
# Processing Record 3 of Set 9 | husavik
# Processing Record 4 of Set 9 | yatou
# Processing Record 5 of Set 9 | cap malheureux
# Processing Record 6 of Set 9 | acajutla
# Processing Record 7 of Set 9 | coahuayana
# Processing Record 8 of Set 9 | moa
# Processing Record 9 of Set 9 | mpika
# Processing Record 10 of Set 9 | presidencia roque saenz pena
# Processing Record 11 of Set 9 | port-gentil
# Processing Record 12 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 13 of Set 9 | garowe
# Processing Record 14 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 9 | porto santo
# Processing Record 16 of Set 9 | la ronge
# Processing Record 17 of Set 9 | lasa
# Processing Record 18 of Set 9 | ahuimanu
# Processing Record 19 of Set 9 | borogontsy
# Processing Record 20 of Set 9 | san andres
# Processing Record 21 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 9 | dekar
# Processing Record 23 of Set 9 | mantua
# Processing Record 24 of Set 9 | chifeng
# Processing Record 25 of Set 9 | saldanha
# Processing Record 26 of Set 9 | areka
# Processing Record 27 of Set 9 | aipe
# Processing Record 28 of Set 9 | kattivakkam
# Processing Record 29 of Set 9 | ambulu
# Processing Record 30 of Set 9 | touros
# Processing Record 31 of Set 9 | piacabucu
# Processing Record 32 of Set 9 | omboue
# Processing Record 33 of Set 9 | constitucion
# Processing Record 34 of Set 9 | bose
# Processing Record 35 of Set 9 | juan lacaze
# Processing Record 36 of Set 9 | chara
# Processing Record 37 of Set 9 | zalantun
# Processing Record 38 of Set 9 | ranghulu
# Processing Record 39 of Set 9 | verkhneuralsk
# Processing Record 40 of Set 9 | aconibe
# Processing Record 41 of Set 9 | tahara
# Processing Record 42 of Set 9 | ancud
# Processing Record 43 of Set 9 | tacuarembo
# Processing Record 44 of Set 9 | abu dhabi
# Processing Record 45 of Set 9 | cacoal
# Processing Record 46 of Set 9 | mocoa
# Processing Record 47 of Set 9 | marsh harbour
# Processing Record 48 of Set 9 | dunedin
# Processing Record 49 of Set 9 | chabahar
# Processing Record 50 of Set 9 | margate
# Processing Record 1 of Set 10 | moose factory
# Processing Record 2 of Set 10 | kohima
# Processing Record 3 of Set 10 | lahad datu
# Processing Record 4 of Set 10 | exeter
# Processing Record 5 of Set 10 | port lincoln
# Processing Record 6 of Set 10 | nador
# Processing Record 7 of Set 10 | bud
# Processing Record 8 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 10 | iqaluit
# Processing Record 10 of Set 10 | berlevag
# Processing Record 11 of Set 10 | kununurra
# Processing Record 12 of Set 10 | swan hill
# Processing Record 13 of Set 10 | san rafael
# Processing Record 14 of Set 10 | verkhoyansk
# Processing Record 15 of Set 10 | labuhan
# Processing Record 16 of Set 10 | adre
# Processing Record 17 of Set 10 | charters towers
# Processing Record 18 of Set 10 | trinidad
# Processing Record 19 of Set 10 | cassilandia
# Processing Record 20 of Set 10 | minchinabad
# Processing Record 21 of Set 10 | sakaraha
# Processing Record 22 of Set 10 | puerto madero
# Processing Record 23 of Set 10 | batemans bay
# Processing Record 24 of Set 10 | shawville
# Processing Record 25 of Set 10 | agutaya
# Processing Record 26 of Set 10 | marathon
# Processing Record 27 of Set 10 | key largo
# Processing Record 28 of Set 10 | grand gaube
# Processing Record 29 of Set 10 | kalomo
# City not found. Skipping...
# Processing Record 30 of Set 10 | okhotsk
# Processing Record 31 of Set 10 | krumovgrad
# Processing Record 32 of Set 10 | baoshan
# Processing Record 33 of Set 10 | vostok
# Processing Record 34 of Set 10 | ruma
# Processing Record 35 of Set 10 | akdepe
# Processing Record 36 of Set 10 | praia da vitoria
# Processing Record 37 of Set 10 | tecoanapa
# Processing Record 38 of Set 10 | scurtu mare
# Processing Record 39 of Set 10 | sucua
# Processing Record 40 of Set 10 | mastic beach
# Processing Record 41 of Set 10 | kemi
# Processing Record 42 of Set 10 | tono
# Processing Record 43 of Set 10 | baruun-urt
# Processing Record 44 of Set 10 | santa rosalia
# Processing Record 45 of Set 10 | uusikaupunki
# Processing Record 46 of Set 10 | cornelio procopio
# Processing Record 47 of Set 10 | ripoll
# Processing Record 48 of Set 10 | morris
# Processing Record 49 of Set 10 | ippy
# Processing Record 50 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 11 | warmbad
# Processing Record 2 of Set 11 | the valley
# Processing Record 3 of Set 11 | egvekinot
# Processing Record 4 of Set 11 | totma
# Processing Record 5 of Set 11 | kulhudhuffushi
# Processing Record 6 of Set 11 | shaowu
# Processing Record 7 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 8 of Set 11 | silver city
# Processing Record 9 of Set 11 | oranjemund
# Processing Record 10 of Set 11 | novaya zaimka
# Processing Record 11 of Set 11 | hasaki
# Processing Record 12 of Set 11 | khuzhir
# Processing Record 13 of Set 11 | zinder
# Processing Record 14 of Set 11 | honiara
# Processing Record 15 of Set 11 | zheleznodorozhnyy
# Processing Record 16 of Set 11 | disraeli
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | mahina
# Processing Record 19 of Set 11 | nampula
# Processing Record 20 of Set 11 | sandviken
# Processing Record 21 of Set 11 | kampenhout
# Processing Record 22 of Set 11 | kavaratti
# Processing Record 23 of Set 11 | mabaruma
# Processing Record 24 of Set 11 | lingao
# Processing Record 25 of Set 11 | fairbanks
# Processing Record 26 of Set 11 | mulanje
# Processing Record 27 of Set 11 | jinchang
# Processing Record 28 of Set 11 | podporozhye
# Processing Record 29 of Set 11 | alushta
# Processing Record 30 of Set 11 | kidero
# Processing Record 31 of Set 11 | ryotsu
# Processing Record 32 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 11 | amnat charoen
# Processing Record 34 of Set 11 | pietarsaari
# Processing Record 35 of Set 11 | adrar
# Processing Record 36 of Set 11 | ketchikan
# Processing Record 37 of Set 11 | fassuta
# Processing Record 38 of Set 11 | ulcinj
# Processing Record 39 of Set 11 | catamarca
# Processing Record 40 of Set 11 | ahmadpur sial
# Processing Record 41 of Set 11 | awjilah
# Processing Record 42 of Set 11 | vila franca do campo
# Processing Record 43 of Set 11 | carolina
# Processing Record 44 of Set 11 | kamenka
# Processing Record 45 of Set 11 | samarai
# Processing Record 46 of Set 11 | dunmore town
# Processing Record 47 of Set 11 | palmer
# Processing Record 48 of Set 11 | cervo
# Processing Record 49 of Set 11 | encruzilhada do sul
# Processing Record 50 of Set 11 | saint anthony
# Processing Record 1 of Set 12 | cadereyta
# Processing Record 2 of Set 12 | gonda
# Processing Record 3 of Set 12 | vredendal
# Processing Record 4 of Set 12 | kingsport
# Processing Record 5 of Set 12 | kloulklubed
# Processing Record 6 of Set 12 | corn island
# Processing Record 7 of Set 12 | fuerte olimpo
# Processing Record 8 of Set 12 | damara
# Processing Record 9 of Set 12 | lexington
# Processing Record 10 of Set 12 | college
# Processing Record 11 of Set 12 | karaton
# Processing Record 12 of Set 12 | moramanga
# Processing Record 13 of Set 12 | gazojak
# Processing Record 14 of Set 12 | ulladulla
# Processing Record 15 of Set 12 | mogok
# Processing Record 16 of Set 12 | iralaya
# Processing Record 17 of Set 12 | chihuahua
# Processing Record 18 of Set 12 | culebra
# Processing Record 19 of Set 12 | port hedland
# Processing Record 20 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 12 | tromso
# Processing Record 22 of Set 12 | charyshskoye
# Processing Record 23 of Set 12 | jasper
# Processing Record 24 of Set 12 | kijang
# Processing Record 25 of Set 12 | sakakah
# Processing Record 26 of Set 12 | honningsvag
# Processing Record 27 of Set 12 | porto seguro
# Processing Record 28 of Set 12 | qeshm
# Processing Record 29 of Set 12 | lavrentiya
# Processing Record 30 of Set 12 | lucea
# Processing Record 31 of Set 12 | sabinas hidalgo
# Processing Record 32 of Set 12 | tautira
# Processing Record 33 of Set 12 | nanyamba
# Processing Record 34 of Set 12 | niamey
# Processing Record 35 of Set 12 | poso
# Processing Record 36 of Set 12 | wieliczka
# Processing Record 37 of Set 12 | udachnyy
# Processing Record 38 of Set 12 | skjervoy
# Processing Record 39 of Set 12 | arlit
# Processing Record 40 of Set 12 | luderitz
# Processing Record 41 of Set 12 | marang
# Processing Record 42 of Set 12 | baie-saint-paul
# Processing Record 43 of Set 12 | tartagal
# Processing Record 44 of Set 12 | rincon
# Processing Record 45 of Set 12 | hirara
# Processing Record 46 of Set 12 | neryungri
# Processing Record 47 of Set 12 | tres arroyos
# Processing Record 48 of Set 12 | slavgorodskoye
# Processing Record 49 of Set 12 | leh
# Processing Record 50 of Set 12 | voskresenskoye
# Processing Record 1 of Set 13 | dingle
# Processing Record 2 of Set 13 | cayenne
# Processing Record 3 of Set 13 | peace river
# Processing Record 4 of Set 13 | gatehouse of fleet
# Processing Record 5 of Set 13 | ailigandi
# Processing Record 6 of Set 13 | swindon
# Processing Record 7 of Set 13 | luena
# Processing Record 8 of Set 13 | anahuac
# Processing Record 9 of Set 13 | deer lake
# Processing Record 10 of Set 13 | eureka
# Processing Record 11 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 13 | tierranueva
# Processing Record 13 of Set 13 | lleida
# Processing Record 14 of Set 13 | genteng
# Processing Record 15 of Set 13 | imeni poliny osipenko
# Processing Record 16 of Set 13 | steamboat springs
# Processing Record 17 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 13 | lundazi
# Processing Record 19 of Set 13 | ordzhonikidze
# Processing Record 20 of Set 13 | broome
# Processing Record 21 of Set 13 | chunskiy
# Processing Record 22 of Set 13 | port pirie
# Processing Record 23 of Set 13 | kupang
# Processing Record 24 of Set 13 | kurchum
# Processing Record 25 of Set 13 | ravar
# Processing Record 26 of Set 13 | hualmay
# Processing Record 27 of Set 13 | ossora
# Processing Record 28 of Set 13 | tumaco
# Processing Record 29 of Set 13 | madimba
# Processing Record 30 of Set 13 | tura
# Processing Record 31 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 13 | sassandra
# Processing Record 33 of Set 13 | bialystok
# Processing Record 34 of Set 13 | kaeo
# Processing Record 35 of Set 13 | port moresby
# Processing Record 36 of Set 13 | giddalur
# Processing Record 37 of Set 13 | melville
# Processing Record 38 of Set 13 | guerrero negro
# Processing Record 39 of Set 13 | cabo rojo
# Processing Record 40 of Set 13 | andijon
# Processing Record 41 of Set 13 | yerbogachen
# Processing Record 42 of Set 13 | cockburn town
# Processing Record 43 of Set 13 | marsciano
# Processing Record 44 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 45 of Set 13 | rio gallegos
# Processing Record 46 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 47 of Set 13 | komsomolskiy
# Processing Record 48 of Set 13 | sokur
# Processing Record 49 of Set 13 | bayir
# Processing Record 50 of Set 13 | hongjiang
# Processing Record 1 of Set 14 | senno
# Processing Record 2 of Set 14 | abha
# Processing Record 3 of Set 14 | vung tau
# Processing Record 4 of Set 14 | gizo
# Processing Record 5 of Set 14 | ust-omchug
# Processing Record 6 of Set 14 | scarborough
# Processing Record 7 of Set 14 | qax
# Processing Record 8 of Set 14 | tucurui
# Processing Record 9 of Set 14 | atlantic city
# Processing Record 10 of Set 14 | juneau
# Processing Record 11 of Set 14 | el cope
# Processing Record 12 of Set 14 | grand-santi
# Processing Record 13 of Set 14 | dawei
# Processing Record 14 of Set 14 | yarmouth
# Processing Record 15 of Set 14 | moranbah
# Processing Record 16 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 14 | jalu
# Processing Record 18 of Set 14 | jega
# Processing Record 19 of Set 14 | oktyabrskoye
# Processing Record 20 of Set 14 | siguiri
# Processing Record 21 of Set 14 | ishimbay
# Processing Record 22 of Set 14 | semey
# Processing Record 23 of Set 14 | saint-francois
# Processing Record 24 of Set 14 | waddan
# Processing Record 25 of Set 14 | straumen
# Processing Record 26 of Set 14 | saint-michel-des-saints
# Processing Record 27 of Set 14 | bacolod
# Processing Record 28 of Set 14 | aksu
# Processing Record 29 of Set 14 | casper
# Processing Record 30 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 31 of Set 14 | lerwick
# Processing Record 32 of Set 14 | uch
# Processing Record 33 of Set 14 | noumea
# Processing Record 34 of Set 14 | dicabisagan
# Processing Record 35 of Set 14 | tessalit
# Processing Record 36 of Set 14 | knysna
# Processing Record 37 of Set 14 | kargapolye
# City not found. Skipping...
# Processing Record 38 of Set 14 | elko
# Processing Record 39 of Set 14 | domoni
# Processing Record 40 of Set 14 | thayetmyo
# Processing Record 41 of Set 14 | bengkalis
# City not found. Skipping...
# Processing Record 42 of Set 14 | victor harbor
# Processing Record 43 of Set 14 | zhanaozen
# Processing Record 44 of Set 14 | oistins
# Processing Record 45 of Set 14 | salinopolis
# Processing Record 46 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 47 of Set 14 | wadi musa
# Processing Record 48 of Set 14 | chauk
# Processing Record 49 of Set 14 | kysyl-syr
# Processing Record 50 of Set 14 | dwarka
# Processing Record 1 of Set 15 | asau
# Processing Record 2 of Set 15 | conceicao do araguaia
# Processing Record 3 of Set 15 | batticaloa
# Processing Record 4 of Set 15 | tubuala
# Processing Record 5 of Set 15 | revda
# Processing Record 6 of Set 15 | kavalerovo
# Processing Record 7 of Set 15 | awbari
# Processing Record 8 of Set 15 | kjopsvik
# Processing Record 9 of Set 15 | correntina
# Processing Record 10 of Set 15 | dodge city
# Processing Record 11 of Set 15 | tazovskiy
# Processing Record 12 of Set 15 | bulawayo
# Processing Record 13 of Set 15 | kibondo
# Processing Record 14 of Set 15 | indramayu
# Processing Record 15 of Set 15 | ambilobe
# Processing Record 16 of Set 15 | santa isabel do rio negro
# Processing Record 17 of Set 15 | longjiang
# Processing Record 18 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 19 of Set 15 | diamantino
# Processing Record 20 of Set 15 | haines junction
# Processing Record 21 of Set 15 | mengcheng
# Processing Record 22 of Set 15 | alibunan
# Processing Record 23 of Set 15 | whyalla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32b267433e99609656502dc92b1364ba&q=whyalla

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 667

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura -46.1927  168.8643     55.96        52          37
# 1  Longyearbyen  78.2186   15.6401     39.04        70          75
# 2  Zaporizhzhya  47.8167   35.1833     58.17        63          83
# 3          Iacu -12.7672  -40.2117     69.84        92           2
# 4  Puerto Ayora  -0.7393  -90.3518     64.54        97          98
# 5         Airai  -8.9266  125.4092     78.19        46          21
# 6          Hilo  19.7297 -155.0900     80.28       100          58
# 7     Saskylakh  71.9167  114.0833     27.10        96         100
# 8         Khash  28.2211   61.2158     71.35         4           0
# 9        Albany  42.6001  -73.9662     47.52        80          53
#
#    Wind Speed Country                 Date Current Description
# 0        6.17      NZ  2022-10-08 05:58:36    scattered clouds
# 1       14.97      SJ  2022-10-08 05:56:30       broken clouds
# 2       12.64      UA  2022-10-08 05:58:37       broken clouds
# 3        3.09      BR  2022-10-08 05:58:37           clear sky
# 4        5.01      EC  2022-10-08 05:58:37     overcast clouds
# 5        4.81      TL  2022-10-08 05:58:38          few clouds
# 6        5.01      US  2022-10-08 05:58:27       broken clouds
# 7       10.27      RU  2022-10-08 05:58:38          light snow
# 8        7.56      IR  2022-10-08 05:58:39           clear sky
# 9        9.31      US  2022-10-08 05:54:47       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Assign a variable to an array of the columns in the order we want them to appear:
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

#Assign a new or the same DataFrame with new column order:
city_data_df = city_data_df[new_column_order]

# print
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     55.96        52          37
# 1  Longyearbyen      SJ  78.2186   15.6401     39.04        70          75
# 2  Zaporizhzhya      UA  47.8167   35.1833     58.17        63          83
# 3          Iacu      BR -12.7672  -40.2117     69.84        92           2
# 4  Puerto Ayora      EC  -0.7393  -90.3518     64.54        97          98
# 5         Airai      TL  -8.9266  125.4092     78.19        46          21
# 6          Hilo      US  19.7297 -155.0900     80.28       100          58
# 7     Saskylakh      RU  71.9167  114.0833     27.10        96         100
# 8         Khash      IR  28.2211   61.2158     71.35         4           0
# 9        Albany      US  42.6001  -73.9662     47.52        80          53
#
#    Wind Speed Current Description
# 0        6.17    scattered clouds
# 1       14.97       broken clouds
# 2       12.64       broken clouds
# 3        3.09           clear sky
# 4        5.01     overcast clouds
# 5        4.81          few clouds
# 6        5.01       broken clouds
# 7       10.27          light snow
# 8        7.56           clear sky
# 9        9.31       broken clouds

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Create the output file (CSV) called WeatherPy_Database.
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
